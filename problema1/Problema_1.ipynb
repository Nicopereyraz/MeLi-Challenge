# %% [markdown]
# ## Insights

# %% [markdown]
# Los insights se incluyen acá para su mejor visibilidad, aunque provienen de todo el desarrollo a continuación.
# Conclusión 1:
# El 49.6% de las ofertas no vendieron nada, y solo el 2,7% de las publicaciones fueron canceladas apenas se hicieron (duración cero).
# Conclusión 2:
# La vertical que más vende con ofertas relámpago es Beauty & Health. No parece ser que sea por un precio unitario menor a los demás ya que las otras verticales no venden muchas cantidades (teniendo o no precios unitarios bajos).
# Conclusión 3:
# Los horarios de inicio que fomentan las ventas son entre las 9 y 11 horas, y entre las 20 y 21 horas. En el gráfico de HORA_INICIO vs SOLD_QUANTITY se ven picos en estos rangos de horas.
# Conclusión y oportunidad:
# A partir de las 8 horas disponible, la oferta relampago no tiene ventas considerables. Se propone cambiarlas una vez que lleguen a las 8 horas disponible. Esto se valida en el scatter plot de DURACION vs SOLD_QUANTITY.

# %%
import os
os.environ['REQUESTS_CA_BUNDLE'] = r'C:\ProgramData\netskope\stagent\data\nscacert.pem'

# %%
# !pip -q install pandas-profiling

# %%
# !pip -q install --user autoviz

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
from datetime import datetime
# Out:
# C:\Temp\12/ipykernel_31592/1256657651.py:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('../ofertas_relampago.csv')

# %%
df.head()
# Out:
#   OFFER_START_DATE      OFFER_START_DTTM          OFFER_FINISH_DTTM       \
# 0    2021-06-22     2021-06-22 16:00:00+00:00  2021-06-22 23:02:43+00:00
# 1    2021-06-22     2021-06-22 13:00:00+00:00  2021-06-22 19:00:02+00:00
# 2    2021-06-22     2021-06-22 07:00:00+00:00  2021-06-22 13:00:01+00:00
# 3    2021-06-22     2021-06-22 19:00:00+00:00  2021-06-23 01:36:12+00:00
# 4    2021-06-22     2021-06-22 13:00:00+00:00  2021-06-22 15:48:12+00:00
#
#      OFFER_TYPE    INVOLVED_STOCK  REMAINING_STOCK_AFTER_END  SOLD_AMOUNT  \
# 0  lightning_deal         4                   -2                  4.72
# 1  lightning_deal         5                    5                   NaN
# 2  lightning_deal        15                   12                 10.73
# 3  lightning_deal        15                   13                  7.03
# 4  lightning_deal        15                    0                 39.65
#
#    SOLD_QUANTITY ORIGIN SHIPPING_PAYMENT_TYPE DOM_DOMAIN_AGG1 VERTICAL  \
# ...

# %%
#Generacion de variable Duracion
a = [datetime.fromisoformat(x) for x in df['OFFER_START_DTTM']]
b = [datetime.fromisoformat(x) for x in df['OFFER_FINISH_DTTM']]
df['DURACION'] = [(b[x]-a[x]).total_seconds() for x in range(len(a))]

# %%
df[df['DURACION']==0]
# Out:
#       OFFER_START_DATE           OFFER_START_DTTM          OFFER_FINISH_DTTM  \
# 25          2021-06-22  2021-06-22 13:00:00+00:00  2021-06-22 13:00:00+00:00
# 72          2021-06-22  2021-06-22 07:00:00+00:00  2021-06-22 07:00:00+00:00
# 90          2021-06-22  2021-06-22 16:00:00+00:00  2021-06-22 16:00:00+00:00
# 98          2021-06-22  2021-06-22 16:00:00+00:00  2021-06-22 16:00:00+00:00
# 145         2021-06-22  2021-06-22 07:00:00+00:00  2021-06-22 07:00:00+00:00
# ...                ...                        ...                        ...
# 48646       2021-06-19  2021-06-19 13:00:00+00:00  2021-06-19 13:00:00+00:00
# 48647       2021-06-19  2021-06-19 19:00:00+00:00  2021-06-19 19:00:00+00:00
# 48700       2021-06-19  2021-06-19 07:00:00+00:00  2021-06-19 07:00:00+00:00
# 48709       2021-06-19  2021-06-19 07:00:00+00:00  2021-06-19 07:00:00+00:00
# 48726       2021-06-19  2021-06-19 07:00:00+00:00  2021-06-19 07:00:00+00:00
#
# ...

# %%
#Generacion de variable precio unitario
df['PRECIO_UNITARIO'] = df['SOLD_AMOUNT']/df['SOLD_QUANTITY']

# %%
df.head()
# Out:
#   OFFER_START_DATE           OFFER_START_DTTM          OFFER_FINISH_DTTM  \
# 0       2021-06-22  2021-06-22 16:00:00+00:00  2021-06-22 23:02:43+00:00
# 1       2021-06-22  2021-06-22 13:00:00+00:00  2021-06-22 19:00:02+00:00
# 2       2021-06-22  2021-06-22 07:00:00+00:00  2021-06-22 13:00:01+00:00
# 3       2021-06-22  2021-06-22 19:00:00+00:00  2021-06-23 01:36:12+00:00
# 4       2021-06-22  2021-06-22 13:00:00+00:00  2021-06-22 15:48:12+00:00
#
#        OFFER_TYPE  INVOLVED_STOCK  REMAINING_STOCK_AFTER_END  SOLD_AMOUNT  \
# 0  lightning_deal               4                         -2         4.72
# 1  lightning_deal               5                          5          NaN
# 2  lightning_deal              15                         12        10.73
# 3  lightning_deal              15                         13         7.03
# 4  lightning_deal              15                          0        39.65
#
#    SOLD_QUANTITY ORIGIN SHIPPING_PAYMENT_TYPE DOM_DOMAIN_AGG1 VERTICAL  \
# ...

# %%
df['HORA_INICIO'] = [datetime.fromisoformat(x).hour for x in df['OFFER_START_DTTM']]

# %%
df
# Out:
#       OFFER_START_DATE      OFFER_START_DTTM          OFFER_FINISH_DTTM       \
# 0        2021-06-22     2021-06-22 16:00:00+00:00  2021-06-22 23:02:43+00:00
# 1        2021-06-22     2021-06-22 13:00:00+00:00  2021-06-22 19:00:02+00:00
# 2        2021-06-22     2021-06-22 07:00:00+00:00  2021-06-22 13:00:01+00:00
# 3        2021-06-22     2021-06-22 19:00:00+00:00  2021-06-23 01:36:12+00:00
# 4        2021-06-22     2021-06-22 13:00:00+00:00  2021-06-22 15:48:12+00:00
# ...                ...                        ...                        ...
# 48741    2021-06-19     2021-06-19 13:00:00+00:00  2021-06-19 19:00:01+00:00
# 48742    2021-06-19     2021-06-19 13:00:00+00:00  2021-06-19 19:00:01+00:00
# 48743    2021-06-19     2021-06-19 07:00:00+00:00  2021-06-19 13:00:03+00:00
# 48744    2021-06-19     2021-06-19 13:00:00+00:00  2021-06-19 19:00:00+00:00
# 48745    2021-06-19     2021-06-19 13:00:00+00:00  2021-06-19 19:00:00+00:00
#
# ...

# %%
#defining the library
profile = ProfileReport(df)
# exporting your report as a html file
profile.to_file(output_file='report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.to_csv('dataset_refinado.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# %matplotlib inline
df = AV.AutoViz('dataset_refinado.csv',chart_format='html' ,save_plot_dir='./resultado')
# Out:
# Shape of your Data Set loaded: (48746, 17)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     17 Predictors classified...
#         3 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 0', 'OFFER_TYPE', 'ORIGIN']
# No scatter plots with depVar when no depVar is given.
# Saving pair_scatters in HTML format
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Row(id='7258', ...)
# Saving distplots_nums in HTML format
# Saving violinplots in HTML format
# No date vars could be found in data set
# Saving heatmaps in HTML format
# Saving cat_var_plots in HTML format
# ...
